# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Genre Quanitity

# %%
#load up the data
movieData = pd.read_csv('movieData_No_Budget.csv', index_col=False)

#rename index
# Rename index
movieData = movieData.set_index('Unnamed: 0')
movieData = movieData.rename_axis('index')

#remove genres
movieData.drop(movieData.index[movieData['genres'] == 0], inplace = True)
movieData.drop(movieData.index[movieData['genres'] == '[]'], inplace = True)

# %% [raw]
# TMDB genre codes
#
# MOVIE
# Action          28
# Adventure       12
# Animation       16
# Comedy          35
# Crime           80
# Documentary     99
# Drama           18
# Family          10751
# Fantasy         14
# History         36
# Horror          27
# Music           10402
# Mystery         9648
# Romance         10749
# Science Fiction 878
# TV Movie        10770
# Thriller        53
# War             10752
# Western         37

# %%
genreCode = [('Action', 28) , ('Adventure' , 12), ('Animation' , 16), ('Comedy' , 35), ('Crime' , 80), ('Documentary' , 99), 
            ('Drama' , 18),('Family' , 10751),('Fantasy' , 14),('History' , 36),('Horror' , 27),('Music' , 10402),
            ('Mystery' , 9648),('Romance' , 10749),('Science Fiction' , 878),('TV Movie' , 10770),('Thriller' , 53),('War' , 10752),
            ('Western' , 37)]

#genreCode

# %%
#convert all the numbers in the genre data frame into strings
genreList = movieData['genres']
genreList_corret = []
genreListFix = []


for item in genreList:
    temp_item = item.replace(' ','')
    if not temp_item == '[]':
        genreList_corret.append(item.replace('[','').replace(']', '').split(','))

for row in genreList_corret:
    for num in row:
        temp_num = int(num)
        for ele in genreCode:
            if temp_num == ele[1]:
                genreListFix.append(ele[0])
                
#genreList_corret

# %%
counts = pd.Series(genreListFix).value_counts()
counts
# Out:
# Drama              976
# Comedy             872
# Thriller           524
# Action             377
# Documentary        351
# Romance            312
# Family             308
# Adventure          247
# Horror             241
# Crime              223
# Science Fiction    187
# Animation          186
# Fantasy            181
# Mystery            143
# TV Movie           142
# Music              125
# History            106
# War                 58
# Western             29
# dtype: int64

# %%
xAxis = np.arange(len(counts))
tick_locations = [value for value in xAxis]

theGenres = list(counts.keys())
theValues = counts
plt.bar(theGenres,theValues,color="red")
plt.xticks(rotation=90)
plt.xlabel("Genres")
plt.ylabel("# of movies")
plt.title("Quantity of movie by genre")

plt.savefig("Images/GenreBarPlot.png")

plt.show()

# %% [markdown]
# ### Conclusion
#
# Drama movies are the most oversaturated type of movie on streaming services right now, with Comedy movies having the second most apperances

# %%
#Reorganize the data a bit differently to pull more statistically significant data
movieList = movieData["Movie"]
genreListT = movieData["genres"]
popularityList = movieData["popularity"]
voteCList = movieData["Vote Count"]
voteMList = movieData["Vote Average"]
genreList_corretT = []
genreListFix = []





movieDict = {
    "movieDict" : movieList,
    "genreDict" : genreListT,
    "popularityDict" : popularityList,
    "voteCDict" : voteCList,
    "voteMDict" : voteMList,
    "genreFix" : [],
}




for items in movieDict["genreDict"]:
    temp_items = items.replace(' ','')
    if not temp_items == '[]':
        genreList_corretT.append(items.replace('[','').replace(']', '').replace(' ','').split(','))
movieDict["genreDict"] = genreList_corretT



for rowT in movieDict["genreDict"]:
    templist = []
    #print(rowT)
    for numT in rowT:
       # print(rowT)
        temp_numT = int(numT)
        for eleT in genreCode:
            if temp_numT == eleT[1]:
                templist.append(eleT[0])
    movieDict["genreFix"].append(templist)
                

movieDataGenre = pd.DataFrame.from_dict(movieDict)

del movieDataGenre['genreDict']
movieDataGenre.columns = ['Movie','Popularity','Vote Count','Vote Average','Genre']

movieDataGenre.head(10)
# Out:
#                                           Movie  Popularity  Vote Count  \
# index
# 0                                  The Irishman      25.287        5490
# 1      David Attenborough: A Life on Our Planet      12.370         231
# 2                                          Roma      14.424        3431
# 3             To All the Boys I've Loved Before      74.988        7636
# 4                            The Social Dilemma      15.102        1251
# 5                                          Okja      21.885        3664
# 6                  The Ballad of Buster Scruggs      33.243        3315
# 7                    The Trial of the Chicago 7      14.451        2411
# 8                                    Article 15       5.601         107
# 9                           Dolemite Is My Name       9.640         946
#
#        Vote Average                                         Genre
# index
# 0               7.6                       [Crime, Drama, History]
# ...

# %%
#genre recategorization
dramaMovies = []
comedyMovies = []
thrillerMovies = []
actionMovies = []
documentaryMovies = []
romanceMovies = []
familyMovies = []
adventureMovies = []
horrorMovies = []
crimeMovies = []
scifiMovies = []
animationMovies = []
fantasyMovies = []
mysteryMovies = []
tvMovies = []
musicMovies = []
historyMovies = []
warMovies = []
westMovies = []

for genre, movie in zip(movieDataGenre["Genre"],movieDataGenre["Movie"]) :
    for strV in genre:
        if (strV == "Drama"):
            dramaMovies.append(movie)
        elif (strV == "Comedy"):
            comedyMovies.append(movie)
        elif (strV == "Thriller"):
            thrillerMovies.append(movie)
        elif (strV == "Action"):
            actionMovies.append(movie)
        elif (strV == "Documentary"):
            documentaryMovies.append(movie)
        elif (strV == "Romance"):
            romanceMovies.append(movie)
        elif (strV == "Family"):
            familyMovies.append(movie)
        elif (strV == "Adventure"):
            adventureMovies.append(movie)
        elif (strV == "Horror"):
            horrorMovies.append(movie)
        elif (strV == "Crime"):
            crimeMovies.append(movie)
        elif (strV == "Science Fiction"):
            scifiMovies.append(movie)
        elif (strV == "Animation"):
            animationMovies.append(movie)
        elif (strV == "Fantasy"):
            fantasyMovies.append(movie)
        elif (strV == "Mystery"):
            mysteryMovies.append(movie)
        elif (strV == "TV Movie"):
            tvMovies.append(movie)
        elif (strV == "Music"):
            musicMovies.append(movie)
        elif (strV == "History"):
            historyMovies.append(movie)
        elif (strV == "War"):
            warMovies.append(movie)
        elif (strV == "Western"):
            westMovies.append(movie)

# %%
#popularity analysis ONLY RUN ONCE
dramaDF = pd.DataFrame()
comedyDF = pd.DataFrame()
thrillerDF = pd.DataFrame()
actionDF = pd.DataFrame()
documentaryDF = pd.DataFrame()
romanceDF = pd.DataFrame()
familyDF = pd.DataFrame()
adventureDF = pd.DataFrame()
horrorDF = pd.DataFrame()
crimeDF = pd.DataFrame()
scifiDF = pd.DataFrame()
animationDF = pd.DataFrame()
fantasyDF = pd.DataFrame()
mysteryDF = pd.DataFrame()
tvDF = pd.DataFrame()
musicDF = pd.DataFrame()
historyDF = pd.DataFrame()
warDF = pd.DataFrame()
westernDF = pd.DataFrame()

for movie in dramaMovies:
    tempDF = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    dramaDF = pd.concat([dramaDF,tempDF])
for movie in comedyMovies:
    tempDF1 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    comedyDF = pd.concat([comedyDF,tempDF1])
for movie in thrillerMovies:
    tempDF2 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    thrillerDF = pd.concat([thrillerDF,tempDF2])
for movie in actionMovies:
    tempDF3 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    actionDF = pd.concat([actionDF,tempDF3])
for movie in documentaryMovies:
    tempDF4 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    documentaryDF = pd.concat([documentaryDF,tempDF4])
for movie in romanceMovies:
    tempDF5 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    romanceDF = pd.concat([romanceDF,tempDF5])
for movie in familyMovies:
    tempDF6 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    familyDF = pd.concat([familyDF,tempDF6])
for movie in adventureMovies:
    tempDF7 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    adventureDF = pd.concat([adventureDF,tempDF7])
for movie in horrorMovies:
    tempDF8 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    horrorDF = pd.concat([horrorDF,tempDF8])
for movie in crimeMovies:
    tempDF9 = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    crimeDF = pd.concat([crimeDF,tempDF9])
for movie in scifiMovies:
    tempDFa = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    scifiDF = pd.concat([scifiDF,tempDFa])
for movie in animationMovies:
    tempDFb = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    animationDF = pd.concat([animationDF,tempDFb])
for movie in fantasyMovies:
    tempDFc = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    fantasyDF = pd.concat([fantasyDF,tempDFc])
for movie in mysteryMovies:
    tempDFd = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    mysteryDF = pd.concat([mysteryDF,tempDFd])
for movie in tvMovies:
    tempDFe = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    tvDF = pd.concat([tvDF,tempDFe])
for movie in musicMovies:
    tempDFf = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    musicDF = pd.concat([musicDF,tempDFf])
for movie in historyMovies:
    tempDFg = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    historyDF = pd.concat([historyDF,tempDFg])
for movie in warMovies:
    tempDFh = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    warDF = pd.concat([warDF,tempDFh])
for movie in westMovies:
    tempDFi = movieDataGenre.loc[movieDataGenre['Movie']==movie]
    westernDF = pd.concat([westernDF,tempDFi])

# %%
genreNames = ['Drama', 'Comedy','Thriller','Action','Documentary','Romance','Family','Adventure',
              'Horror','Crime','Science Fiction','Animation','Fantasy','Mystery','TV Movie','Music','History','War','Western']

dra = dramaDF["Popularity"]
com = comedyDF["Popularity"]
thr = thrillerDF["Popularity"]
act = actionDF["Popularity"]
docu = documentaryDF["Popularity"]
roma = romanceDF["Popularity"]
fam = familyDF["Popularity"]
adv = adventureDF["Popularity"]
hor = horrorDF["Popularity"]
cri = crimeDF["Popularity"]
sci = scifiDF["Popularity"]
ani = animationDF["Popularity"]
fant = fantasyDF["Popularity"]
mys = mysteryDF["Popularity"]
tv = tvDF["Popularity"]
mus = musicDF["Popularity"]
his = historyDF["Popularity"]
war = warDF["Popularity"]
wes = westernDF["Popularity"]

data = [dra, com, thr, act, docu, roma, fam, adv, hor, cri, sci, ani, fant, mys, tv, mus, his, war,wes]

fig = plt.figure()

#axes instance
ax = fig.add_axes([0,19,3,2])
plt.boxplot(data,labels=genreNames, flierprops = dict(markerfacecolor = 'g', marker = 'o'))
ax.set_title('Genre by Popularity')
ax.set_ylabel('Popularity')

plt.savefig("Images/boxNwhiskersPlot.png")

plt.show()

# %% [markdown]
# # Final Conclusion

# %% [markdown]
# Even though Drama and Comedy movies have the most quanitity on the market, they bolster a much lower average on popularity* compared to other genres such as Adventure and Fantasy

# %% [markdown]
# ![image.png](attachment:image.png)
